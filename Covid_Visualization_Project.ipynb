# %%
import pandas as pd
import datetime

# %%
data=pd.read_csv('FINAL.csv')
data
# Out:
#            date country state  county  fips  lat  long          locationId  \
# 0    2020-03-02      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 1    2020-03-03      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2    2020-03-04      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 3    2020-03-05      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 4    2020-03-06      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# ..          ...     ...   ...     ...   ...  ...   ...                 ...
# 496  2021-06-21      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 497  2021-06-22      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 498  2021-06-23      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 499  2021-06-24      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 500  2021-06-25      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
#
#      actuals.cases  actuals.deaths  ...  metrics.infectionRate  \
# ...

# %%
data[data.duplicated()]
# Out:
#            date country state  county  fips  lat  long          locationId  \
# 63   2020-03-02      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 64   2020-03-03      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 65   2020-03-04      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 66   2020-03-05      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 67   2020-03-06      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 68   2020-03-07      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 69   2020-03-08      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 70   2020-03-09      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 71   2020-03-10      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 72   2020-03-11      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 294  2020-09-25      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# ...

# %%
data['actuals.newDeaths'].sum() #new deaths
# Out:
# 27827.0

# %%
data['actuals.newCases'].sum() #new cases
# Out:
# 1222533.0

# %%
data['metrics.vaccinationsCompletedRatio'].sum() #Ratio of population that has completed vaccination
# Out:
# 34.715

# %%
data['metrics.vaccinationsInitiatedRatio'].sum() #Ratio of population that has initiated vaccination
# Out:
# 53.867999999999995

# %%
data['actuals.deaths'].cumsum() #Cumulative deaths that are suspected or confirmed
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            0.0
#          ...
# 496    6263708.0
# 497    6291363.0
# 498    6319025.0
# 499    6346700.0
# 500          NaN
# Name: actuals.deaths, Length: 501, dtype: float64

# %%
data['actuals.cases'].cumsum() #Cumulative confirmed or suspected cases.
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              2.0
#           ...
# 496    223181580.0
# 497    224396819.0
# 498    225612193.0
# 499    226827928.0
# 500            NaN
# Name: actuals.cases, Length: 501, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
# a scatter plot comparing num_children and num_pets
data.plot(kind='line',x='actuals.cases',y='metrics.vaccinationsCompletedRatio',color='blue')
plt.show()
